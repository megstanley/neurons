# %% [markdown]
# # Inspecting the arrangement of neurons in xy

# %% [markdown]
# The time-series data is extracted for neurons, where the centre of each 'blob' identified as a neuron is recorded as pixel coordinates in x and y. The pixel size is 0.295 microns, and each z plane represents 4 microns.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = np.load('/Users/Megan/data_analysis/Aug02_2018_B3/B3_TS/Extracted/rg_B3_TS_ZP_1.npz')

# %%
coords = data['xy']

# %%
plt.scatter(coords[:,0], coords[:,1])
plt.xlabel('x pixel')
plt.ylabel('y pixel')
# Out:
# Text(0,0.5,'y pixel')

# %% [markdown]
# Aha! We know from the images that some of these data points are 'real' in that it seems like they could be neurons. However, many of those crowded around the edge of the image are artifacts. It would be good to clean up the data by first removing any points from a small range at the edges of the image.

# %%
max_x = max(coords[:,0])
max_x
# Out:
# 693.0

# %%
max_y = max(coords[:,1])
max_y
# Out:
# 788.0

# %% [markdown]
# Before we go further: each cell is represented in multiple z stacks. We need a function to preprocess all of the data and in effect 'join together' all of the different z stacks, so that we have a full volume of cells represented. If we do not do this, we will only be finding correlations between cells in a plane.

# %% [markdown]
# Using the functions in the 'preprocess' folder in 'join_z_stacks.py' I have an array of all the x,y, and z positions for every cell found in this dataset. Some of these will be redundant; plotting will be helpful to understand the parameters needed to filter these out in preprocessing.

# %%
xyzdata = np.load('/Users/Megan/data_analysis/Aug02_2018_B3/B3_TS/all_coords/xyzarray.npz')

# %% [markdown]
# Actually, that proved to be too big to plot right now. Need to figure out a better way to do it.
#
# Using neurons/data_cleaning/data_cleaning.py with the function find_edges to see whether we can find and then remove obvious edge artifacts. Let's have a look at the example to test it, using a 10 pixel margin.

# %%
removed_edge_data = np.load('/Users/Megan/data_analysis/Aug02_2018_B3/B3_TS/rg_B3_TS_ZP_1_removed_edges10.npz')

# %%
removed_edge_data.keys()
# Out:
# ['arr_0']

# %%
coords = removed_edge_data['arr_0']

# %%
coords.shape
# Out:
# (224, 3)

# %%
plt.scatter(coords[:,0], coords[:,1])
plt.xlabel('x pixel')
plt.ylabel('y pixel')
# Out:
# Text(0,0.5,'y pixel')

# %% [markdown]
# This has worked rather well. We should check we are not cropping too many or too few. Let's try a couple of other examples just to get an understanding of the data.

# %%
removed_edge_data100 = np.load('/Users/Megan/data_analysis/Aug02_2018_B3/B3_TS/rg_B3_TS_ZP_1_removed_edges100.npz')

# %%
coords100 = removed_edge_data100['arr_0']

# %%
coords100.shape
# Out:
# (123, 3)

# %%
plt.scatter(coords100[:,0], coords100[:,1])
plt.xlabel('x pixel')
plt.ylabel('y pixel')
# Out:
# Text(0,0.5,'y pixel')

# %% [markdown]
# Yes, cropping works correctly, but 100 pixels is obviously too harsh. We can scale it back to 5 to have a look.

# %%
removed_edge_data5 = np.load('/Users/Megan/data_analysis/Aug02_2018_B3/B3_TS/rg_B3_TS_ZP_1_removed_edges5.npz')

# %%
coords5 = removed_edge_data5['arr_0']

# %%
plt.scatter(coords5[:,0], coords5[:,1])
plt.xlabel('x pixel')
plt.ylabel('y pixel')
# Out:
# Text(0,0.5,'y pixel')

# %% [markdown]
# This is no different from the 10 pixel data. I suspect the corner ones are artifacts, so in fact the margin needs to increase slightly. Let's just test it on a completely different slice with many artifacts.

# %%
data20 = np.load('/Users/Megan/data_analysis/Aug02_2018_B3/B3_TS/Extracted/rg_B3_TS_ZP_20.npz')
coords20 = data20['xy']
plt.scatter(coords20[:,0], coords20[:,1],c='r')
plt.xlabel('x pixel')
plt.ylabel('y pixel')
# Out:
# Text(0,0.5,'y pixel')

# %%
data20_remv = np.load('/Users/Megan/data_analysis/Aug02_2018_B3/B3_TS/rg_B3_TS_ZP_20_removed_edges15.npz')
coords20_remv = data20_remv['arr_0']
plt.scatter(coords20[:,0], coords20[:,1],c='r')
plt.scatter(coords20_remv[:,0], coords20_remv[:,1],c='b')
plt.xlabel('x pixel')
plt.ylabel('y pixel')
# Out:
# Text(0,0.5,'y pixel')

# %% [markdown]
# OK, so it seems to work, although some work needs to be done to find the best cropping parameters.
